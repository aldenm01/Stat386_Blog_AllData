# %%
fe = pd.read_csv('C:/Users/VonVarley/Downloads/fire_emblem_updated.csv')
fe = fe[fe['Votes'] <= 10000]
feMale = fe[fe['Gender'] == 'Male']
feMaleArmor = feMale[feMale['Type'] == 'Armored']
feMaleInf = feMale[feMale['Type'] == 'Infantry']
feMaleFlying = feMale[feMale['Type'] == 'Flying']
feMaleMagic = feMale[feMale['Type'] == 'Magic']
feMaleBeast = feMale[feMale['Type'] == 'Beast']
feMaleCavalry = feMale[feMale['Type'] == 'Cavalry']
feFemale = fe[fe['Gender'] == 'Female']
feFemaleArmor = feFemale[feFemale['Type'] == 'Armored']
feFemaleInf = feFemale[feFemale['Type'] == 'Infantry']
feFemaleFlying = feFemale[feFemale['Type'] == 'Flying']
feFemaleMagic = feFemale[feFemale['Type'] == 'Magic']
feFemaleBeast = feFemale[feFemale['Type'] == 'Beast']
feFemaleCavalry = feFemale[feFemale['Type'] == 'Cavalry']

# %%
feshort = fe[['Str', 'Def', 'Votes']]

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ['Infantry', 'Knights', 'Fliers', 'Mages', 'Beasts', 'Cavalry']
men_means = [round(feMaleInf['Votes'].mean(), 0), round(feMaleArmor['Votes'].mean(), 0), round(feMaleFlying['Votes'].mean(), 0), 
             round(feMaleMagic['Votes'].mean(), 0), round(feMaleBeast['Votes'].mean(), 0), round(feMaleCavalry['Votes'].mean(), 0)]

women_means = [round(feFemaleInf['Votes'].mean(), 0), round(feFemaleArmor['Votes'].mean(), 0), round(feFemaleFlying['Votes'].mean(), 0), 
               round(feFemaleMagic['Votes'].mean(), 0), round(feFemaleBeast['Votes'].mean(), 0), round(feFemaleCavalry['Votes'].mean(), 0)]

x = np.arange(len(labels))  # the label locations
width = 0.37  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Males', edgecolor = "black")
rects2 = ax.bar(x + width/2, women_means, width, label='Females', color = 'pink', edgecolor = "black")

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Character Type')
ax.set_ylabel('Votes')
ax.set_title('Popularity and Gender in Video Games')
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()
fig.set_size_inches(10, 5)
plt.ylim(0, 3200)
plt.figure(figsize=(10, 20))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ['Infantry', 'Knights', 'Fliers', 'Mages', 'Beasts', 'Cavalry', 'Overall']
men_means = [round(feMaleInf['Votes'].mean(), 0), round(feMaleArmor['Votes'].mean(), 0), round(feMaleFlying['Votes'].mean(), 0), 
             round(feMaleMagic['Votes'].mean(), 0), round(feMaleBeast['Votes'].mean(), 0), round(feMaleCavalry['Votes'].mean(), 0), round(feMale['Votes'].mean(), 0)]

women_means = [round(feFemaleInf['Votes'].mean(), 0), round(feFemaleArmor['Votes'].mean(), 0), round(feFemaleFlying['Votes'].mean(), 0), 
               round(feFemaleMagic['Votes'].mean(), 0), round(feFemaleBeast['Votes'].mean(), 0), round(feFemaleCavalry['Votes'].mean(), 0), round(feFemale['Votes'].mean(), 0)]

x = np.arange(len(labels))  # the label locations
width = 0.37  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Males', edgecolor = "black")
rects2 = ax.bar(x + width/2, women_means, width, label='Females', color = 'pink', edgecolor = "black")

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Character Type')
ax.set_ylabel('Votes')
ax.set_title('Female Popularity in Video Games')

# Title could be what I want them to take away
# Female Popularity in Video Games


ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()
fig.set_size_inches(10, 5)
plt.ylim(0, 3200)
plt.figure(figsize=(10, 20))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ['Infantry', 'Knights', 'Fliers', 'Mages', 'Beasts', 'Cavalry']
men_means = [round(feMaleInf['Str'].mean(), 0), round(feMaleArmor['Str'].mean(), 0), round(feMaleFlying['Str'].mean(), 0), 
             round(feMaleMagic['Str'].mean(), 0), round(feMaleBeast['Str'].mean(), 0), round(feMaleCavalry['Str'].mean(), 0)]

women_means = [round(feFemaleInf['Str'].mean(), 0), round(feFemaleArmor['Str'].mean(), 0), round(feFemaleFlying['Str'].mean(), 0), 
               round(feFemaleMagic['Str'].mean(), 0), round(feFemaleBeast['Str'].mean(), 0), round(feFemaleCavalry['Str'].mean(), 0)]

x = np.arange(len(labels))  # the label locations
width = 0.37  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Males', edgecolor = "black")
rects2 = ax.bar(x + width/2, women_means, width, label='Females', color = 'pink', edgecolor = "black")

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Character Type')
ax.set_ylabel('Average Strength')
ax.set_title('Strength and Gender in Video Games')
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()
fig.set_size_inches(10, 5)
plt.ylim(0, 70)
plt.figure(figsize=(10, 20))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ['Infantry', 'Knights', 'Fliers', 'Mages', 'Beasts', 'Cavalry', 'Overall']
men_means = [round(feMaleInf['Str'].mean(), 0), round(feMaleArmor['Str'].mean(), 0), round(feMaleFlying['Str'].mean(), 0), 
             round(feMaleMagic['Str'].mean(), 0), round(feMaleBeast['Str'].mean(), 0), round(feMaleCavalry['Str'].mean(), 0), round(feMale['Str'].mean(), 0)]

women_means = [round(feFemaleInf['Str'].mean(), 0), round(feFemaleArmor['Str'].mean(), 0), round(feFemaleFlying['Str'].mean(), 0), 
               round(feFemaleMagic['Str'].mean(), 0), round(feFemaleBeast['Str'].mean(), 0), round(feFemaleCavalry['Str'].mean(), 0), round(feFemale['Str'].mean(), 0)]

x = np.arange(len(labels))  # the label locations
width = 0.37  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Males', edgecolor = "black")
rects2 = ax.bar(x + width/2, women_means, width, label='Females', color = 'pink', edgecolor = "black")

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Average Strength')
ax.set_title('Strength and Gender in Video Games')
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()
fig.set_size_inches(10, 5)

plt.ylim(0, 70)

plt.figure(figsize=(10, 20))

plt.show()
