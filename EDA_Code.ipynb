# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import math as math

# %%
fe = pd.read_csv('fire_emblem_updated.csv')
fe = fe[['Name', 'Class', 'Type', 'HP', 'Str', 'Mag', 'Skl', 'Spd', 'Lck', 'Def', 'Res', 'Mov', 'Votes', 'Game', 'Gender']]

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize = a4_dims)
sns.boxplot(x = fe['Type'], y = fe['Votes'], hue = fe['Gender'])
plt.legend(bbox_to_anchor=(1.02, 0.10), loc='upper left', borderaxespad=0)
plt.title('Class Types and Character Popularity Boxplot')
plt.xlabel('Class Type')
plt.ylabel('Votes')
# Out:
# Text(0, 0.5, 'Votes')

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize = a4_dims)
sns.boxplot(x = few_votes['Type'], y = few_votes['Votes'], hue = few_votes['Gender'])
plt.legend(bbox_to_anchor=(1.02, 0.10), loc='upper left', borderaxespad=0)

# %%
infantry = few_votes[few_votes['Type'] == 'Infantry']
sns.regplot(x='Str', y='Def', data=infantry)
plt.title('Strength/Defense Correlation Chart for infantry Units')
plt.xlabel('Strength')
plt.ylabel('Defense')
plt.savefig('test')

# %%
sns.regplot(x='Str', y='Def', data=fe)
plt.title('Strength/Defense Correlation Chart for All Units')
plt.xlabel('Strength')
plt.ylabel('Defense')
plt.savefig('test')

# %%
few_votes = test[test['Votes'] < 6000]

# %%
Armored = fe[fe['Type'] == 'Armored']
matrix = Armored.corr(
    method = 'pearson',  # The method of correlation
    min_periods = 1      # Min number of observations required
)

matrix = Armored.corr().round(2)
sns.heatmap(matrix, annot=True, cmap=plt.get_cmap('YlGnBu')).set_title('Armored Correlation Matrix')
plt.show()

# %%
matrix = infantry.corr(
    method = 'pearson',  # The method of correlation
    min_periods = 1      # Min number of observations required
)

matrix = infantry.corr().round(2)
sns.heatmap(matrix, annot=True, cmap=plt.get_cmap('YlOrRd')).set_title('Infantry Correlation Matrix')
plt.show()

# %%
Beast = fe[fe['Type'] == 'Beast']
matrix = Armored.corr(
    method = 'pearson',  # The method of correlation
    min_periods = 1      # Min number of observations required
)

matrix = Beast.corr().round(2)
sns.heatmap(matrix, annot=True, cmap=plt.get_cmap('rocket')).set_title('Beast Correlation Matrix')
plt.show()

# %%
Flying = fe[fe['Type'] == 'Flying']
matrix = Armored.corr(
    method = 'pearson',  # The method of correlation
    min_periods = 1      # Min number of observations required
)

matrix = Flying.corr().round(2)
sns.heatmap(matrix, annot=True, cmap=plt.get_cmap('ocean')).set_title('Flying Correlation Matrix')
plt.show()

# %%
Cavalry = fe[fe['Type'] == 'Cavalry']
matrix = Armored.corr(
    method = 'pearson',  # The method of correlation
    min_periods = 1      # Min number of observations required
)

matrix = Cavalry.corr().round(2)
sns.heatmap(matrix, annot=True, cmap=plt.get_cmap('Accent')).set_title('Cavalry Correlation Matrix')
plt.show()

# %%
matrix = fe.corr(
    method = 'pearson',  # The method of correlation
    min_periods = 1      # Min number of observations required
)

matrix = fe.corr().round(2)
sns.heatmap(matrix, annot=True, cmap=plt.get_cmap('Oranges')).set_title('Correlation Matrix for All Units')
plt.show()
